# %% [markdown]
# #**Calificaciones de Estudiantes**
#
# ##**Introducción**
#
# En el ámbito educativo, el rendimiento académico es un tema que ha llevado a realizar muchas investigaciones debido al impacto que tiene en los estudiantes, ya que existen muchos factores que afectan las calificaciones que obtienen.
#
# Algunos de estos factores son el número de cursos y el tiempo de estudio, al analizar estos elementos, podemos predecir cómo se desempeñarán los alumnos y aplicar estrategias que les ayuden a aprender y a mejorar sus calificaciones.
#
#
# El propósito de este proyecto es analizar un conjunto de datos con el fin de identificar los factores y la manera que influyen en las calificaciones obtenidas por los estudiantes.
#
#
# ##**Hipótesis**
#
# Existe una relación positiva entre el tiempo de estudio y las calificaciones de los estudiantes, debido a que entre más tiempo inviertan estudiando, mejores serán sus resultados.
#
#
# ##**Marco teórico**
#
# El entorno educativo en la actualidad ha tomado un papel fundamental en la vida de las personas, debido al aprendizaje que se puede adquirir para alcanzar metas futuras. Cada vez más, hay personas que aprovechan la oportunidad de seguir estudiando para alcanzar lo que desean.
#
# Aún así, es importante mencionar que existen elementos que intervienen en el aprendizaje, lo que lleva a que las personas no obtengan la productividad que esperan.
#
# Diversas investigaciones han demostrado que el rendimiento académico de los estudiantes puede verse influido por varios factores. Algunos de estos son:
#
# *   **Número de cursos:** El número de cursos que un estudiante toma influye mucho, ya que entre más cursos tenga será más pesada su carga académica, lo que afecta su rendimiento.
# *   **Tiempo de estudio:** El tiempo que un alumno invierte estudiando influye demasiado en sus calificaciones finales, ya que una persona que estudia mucho es probable que tenga mejores resultados.
#
#
# Es por eso que, el principal objetivo de este análisis es descubrir como intervienen estos factores en las calificaciones de los estudiantes, es decir si uno influye al otro. Para esto la regresión lineal simple es útil ya que nos ayudará a saber la relación que existe entre estas variables.
#
# El modelo de regresión lineal simple es una fórmula matemática que trata de encontrar la relación que existe entre dos variables usando una linea recta.
# Está representada como: Y = β0 + β1X + ϵ
#
#
# Los **supuestos** del modelo son los siguientes:
#
#
# *   **Linealidad**:Existe relación lineal entre las dos variables
# *   **Independencia**: Los datos no dependen unos de otros.
# *   **Homoscedasticidad**: Los puntos se distribuyen con la misma dispersión, tienen la misma varianza.
#
#
# El **coeficiente de correlación** nos servirá para medir la relación entre las variables
#
# Se representa como: -1 ≤ r ≤ 1
#
# Donde:
#
# *   1 = Relación fuerte y positiva.
# *  -1 = Relación fuerte y negativa.
# *   0 = Sin relación lineal.
#
# El **coeficiente de determinación** nos dirá que porcentaje se puede explicar con la variable que usamos para hacer la predicción
#
# Se representa como: 0 ≤ r2 ≤ 1
#
# Donde:
#
# *   1 = Predicción perfecta.
# *   0 = No hay relación.
#
# El **test de Shapiro** nos ayudará a comprobar si los datos siguen una distribución normal.
#
# Las hipótesis son las siguientes:
#
# *   𝐻0: Los datos siguen una distribución normal.
# *   𝐻1: Los datos no siguen una distribución normal.
#
# El **test de Breusch-Pagan** detectará si hay heteroscedasticidad en el modelo.
#
# Las hipótesis son las siguientes:
#
# *   𝐻0: Hay homoscedasticidad.
# *   𝐻1: Hay heteroscedasticidad.
#
# El **ANOVA** nos servirá para verificar si la pendiente de la regresión es estadísticamente significativa.
#
# Las hipótesis son las siguientes:
#
# *   𝐻0: β1 = 0.
# *   𝐻1: β1 ≠ 0.
#
# Realizar este análisis nos dará información para saber si el tiempo que los alumnos dedican al estudio tiene un efecto significativo en sus calificaciones.
#
#
# ##**Metodología**
#
# 1. Seleccionar las Variables
#
# *   Variable independiente (X): Tiempo de estudio (Time study)
# *   Variable dependiente (Y): Calificaciones (Marks)
#
# 2. Crear un gráfico de dispersión
# Se realiza un gráfico de dispersión para visualizar la relación entre el tiempo de estudio y las calificaciones.
#
# 3. Calcular el Coeficiente de Correlación de Pearson
# Se calcula el coeficiente de correlación (r), que mide la fuerza de la relación lineal entre las dos variables. Un valor cercano a 1 indica una fuerte relación positiva, mientras que un valor cercano a -1 indica una fuerte relación negativa, en cambio si el valor es 0 indica que no hay relación.
#
# 4. Calcular el Coeficiente de Determinación
# El coeficiente de determinación (r²) se calcula para conocer qué porcentaje de la variabilidad de las calificaciones (Y) se puede explicar por el tiempo de estudio (X).
#
# 5. Calcular la Recta de Regresión Lineal
# Se calcula la recta de regresión lineal, que representa la línea recta que mejor se adapta a los puntos y con ella se observa la relación entre el tiempo de estudio y las calificaciones.
#
# 6. Calcular el Intervalo de Confianza del 95% para b1
# Se calcula el intervalo de confianza del 95% para el valor de b1, esto proporciona un rango dentro del cual se espera que se encuentre el valor verdadero de la pendiente.
#
# 7. Calcular los residuales
# Se calculan los residuales, estos nos permiten verificar los supuestos como la linealidad, homoscedasticidad y la normalidad de errores.
#
# 8. Calcular la prueba de Shapiro
# Se realiza la prueba de Shapiro para verificar si los residuales siguen una distribución normal, lo cual es un supuesto importante en la regresión lineal.
#
# 9. Calcular la prueba de Breusch-Pagan
# Se realiza la prueba de Breusch-Pagan para identificar si existe heteroscedasticidad, es decir, si existe una varianza diferente.
#
# 10. Realizar una tabla ANOVA
# Se realiza una tabla ANOVA para verificar si el modelo de regresión es estadísticamente significativo, lo que evalúa si el tiempo de estudio tiene un impacto real en las calificaciones.
#
#
# ##**Resultados**:

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Elizabeth341/Estadistica/refs/heads/main/Student_Marks.csv")
df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
X = df.get('time_study')
Y = df.get('Marks')


# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.scatter(X, Y, color = 'red')
plt.xlabel('Time study')
plt.ylabel('Marks')
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


# 3. Calcule el coeficiente de correlación.
from scipy.stats import pearsonr
r, _ = pearsonr(X, Y)
print(f'Coeficiente de correlación: {r:0.4f}\n')


# 4. Calcule el coeficiente de determinación.
from sklearn.metrics import r2_score
r2 = r2_score(Y, Yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')


# 5. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()

b0, b1 = modelo.params

fun = lambda x: b0 + b1 * x

Yc = fun(X)

plt.plot(X, Yc, color = 'blue', linestyle = '--')


# 6. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada (b1)
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')


# 7. Calcule los residuales y trace un nuevo gráfico de dispersión.
residuales = modelo.resid
plt.figure()
plt.scatter(X, residuales, color = 'green')
plt.xlabel('Time study')
plt.ylabel('Residuales')
ax= plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


# 8.Realice la prueba de Shapiro para los residuales.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')


#9. Realice la prueba de Brausch-Pagan para los residuales.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')


#10. Realice una tabla ANOVA.
from statsmodels.formula.api import ols
# Y ~ X
modelo_2 = ols('Marks ~ time_study', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_2)
tabla_anova
# Out:
# Coeficiente de correlación: 0.9423
#
# Coeficiente de determinación:  0.8878
#
# intervalo de confianza para b1 de  95%
#  5.2834 < b1 <  6.0941
#
# valor-p de Shapiro:  0.0042
#
# valor_p de Breusch-Pagan:  0.7591
#               df        sum_sq       mean_sq           F        PR(>F)
# time_study   1.0  18039.853486  18039.853486  775.770433  2.355657e-48
# Residual    98.0   2278.903097     23.254113         NaN           NaN

# %% [markdown]
# ##**Conclusión**
#
# En conclusión, podemos decir que el tiempo que los estudiantes dedican al estudio tiene un gran impacto en sus calificaciones. A medida que los estudiantes pasan más tiempo estudiando, sus calificaciones tienden a mejorar, lo que confirma la hipótesis de que el tiempo de estudio es clave para obtener buenos resultados académicos.
#
# El análisis muestra que la relación entre las horas de estudio y las calificaciones no solo es positiva, sino también bastante fuerte, lo que significa que las calificaciones de los estudiantes están muy influenciadas por el tiempo que dedican al estudio. En general, cuanto más tiempo se invierta en estudiar, mayores serán las posibilidades de obtener buenos resultados.
#
# Este resultado destaca la importancia de estudiar de manera constante, ya que dedicar más tiempo al estudio puede mejorar el rendimiento académico. Sin embargo, es importante tener en cuenta que aunque el tiempo de estudio es muy importante, también influyen otros factores como las técnicas de estudio, la motivación y el entorno en el que se estudia.
